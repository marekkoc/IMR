# %% [markdown]
# Created: 2020.07.20
#
# Modified: 2020.07.11

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

import random
import pandas as pd
from pathlib import Path

# %%
import sys
sys.path.append('functions')

# %aimport functions00, functions01
from functions00 import *
from functions01 import *

import functions32 as f32

# %%
mk_get_host_info()
# Out:
# **********************************************************************************************************************************
# Settings:
# 	HOST:  mmiv-ml-titan
# 	PATH_ROOT_DATA:  /data-10tb/shared/skull/train-3d-iso
# 	PATH_GIT_HUB:  /data-10tb/marek/github_codes/skull-stripping-1/fastai
# 	PATH_2D: /data-10tb/shared/skull
#
# 3D DFs paths (_mk_3D):
# 	IXI_TEST_3D: /data-10tb/marek/github_codes/skull-stripping-1/fastai/2.2_train_valid_test_sets/ixi_test_mk_3d.csv
# 	TEST_3D : /data-10tb/marek/github_codes/skull-stripping-1/fastai/2.2_train_valid_test_sets/test_mk_3d.csv
# 	TRAIN_VAL_3D: /data-10tb/marek/github_codes/skull-stripping-1/fastai/2.2_train_valid_test_sets/train_val_mk_3d.csv
# 	NFBS_TEST_3D: /data-10tb/marek/github_codes/skull-stripping-1/fastai/2.2_train_valid_test_sets/nfbs_test_mk_3d.csv
#
# Error files (pickle):
# 	ERROR_FILES: /data-10tb/marek/github_codes/skull-stripping-1/fastai/2.2_train_valid_test_sets/error_files
# **********************************************************************************************************************************

# %% [markdown]
# # 2D AXIAL - T1 biascorr

# %%
folder_path = PATH_2D /'axial-2d'

df = pd.read_csv(folder_path/'bias_mask-test-val-axial-2d.csv')
print(df.shape)
df.head(3)
# Out:
# (469116, 6)
#                                root  \
# 0  /data-10tb/shared/skull/axial-2d
# 1  /data-10tb/shared/skull/axial-2d
# 2  /data-10tb/shared/skull/axial-2d
#
#                                                      bias_path  \
# 0  /train/ADNI/ADNI_003_S_0931_MR_MPR-R__GradWarp__B1_Corre...
# 1  /train/ADNI/ADNI_003_S_0931_MR_MPR-R__GradWarp__B1_Corre...
# 2  /train/ADNI/ADNI_003_S_0931_MR_MPR-R__GradWarp__B1_Corre...
#
#                                                image_full_path  \
# 0  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...
# 1  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...
# 2  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...
#
#                                                 mask_full_path usage_txt  \
# 0  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...     train
# 1  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...     train
# 2  /data-10tb/shared/skull/axial-2d/train/ADNI/ADNI_003_S_0...     train
#
#    usage
# 0  False
# 1  False
# 2  False

# %% [markdown]
# #### Create DataBunch

# %%
# item list
il = SegmentationItemList.from_df(df, folder_path, cols='bias_path', convert_mode='L')

# %%
# split data
sd = il.split_from_df(col='usage')

# %%
codes = np.loadtxt(folder_path/'codes.txt', dtype=str); codes
# Out:
# array(['background', 'brain'], dtype='<U10')

# %%
# label list
ll = sd.label_from_df(cols='mask_full_path', classes=codes)

# %%
tmfs2 = get_transforms(do_flip=True, flip_vert=False,
                      max_rotate=15, max_zoom=1.05,
                      max_lighting=0.2, max_warp=None,
                      p_affine=0.5, p_lighting=0.5
                      )
bs=128
size = 128

# %%
ll = ll.transform(tmfs2, tfm_y=True, size=size, padding_mode='zeros', resize_method=ResizeMethod.PAD)

# %%
data = ll.databunch(bs=bs).normalize(imagenet_stats)

# %%
data.train_ds[0]
# Out:
# (Image (1, 128, 128), ImageSegment (1, 128, 128))

# %%
data.show_batch(7, figsize=(16,16))

# %%
# free = gpu_mem_get_free_no_cache()
# # the max size of bs depends on the available GPU RAM
# if free > 8200: bs=16
# else:           bs=8
# print(f"using bs={bs}, have {free}MB of GPU RAM free")

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=dice, wd=wd)

# %%
lr_find(learn)
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='67' class='' max='2796', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.40% [67/2796 01:49<1:14:21 0.9470]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 5.25E-05
# Min loss divided by 10: 6.31E-04

# %%
lr=1e-4

# %%
learn.fit_one_cycle(15, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.021414</td>
#       <td>0.023713</td>
#       <td>0.917243</td>
#       <td>51:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.017188</td>
#       <td>0.020890</td>
#       <td>0.926185</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.015430</td>
#       <td>0.019177</td>
#       <td>0.936290</td>
#       <td>26:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014681</td>
#       <td>0.018528</td>
#       <td>0.939865</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.013723</td>
#       <td>0.018510</td>
#       <td>0.942099</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.013209</td>
#       <td>0.018252</td>
#       <td>0.942940</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.012616</td>
#       <td>0.019403</td>
#       <td>0.943570</td>
#       <td>26:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012141</td>
#       <td>0.018254</td>
#       <td>0.943308</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.011880</td>
#       <td>0.019690</td>
#       <td>0.943988</td>
#       <td>26:45</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.011738</td>
#       <td>0.019637</td>
#       <td>0.943493</td>
#       <td>26:45</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.011483</td>
#       <td>0.020320</td>
#       <td>0.944164</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.011165</td>
#       <td>0.020322</td>
#       <td>0.944563</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.011085</td>
#       <td>0.020578</td>
#       <td>0.944383</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.011149</td>
#       <td>0.020554</td>
#       <td>0.944760</td>
#       <td>26:46</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.011064</td>
#       <td>0.020660</td>
#       <td>0.944642</td>
#       <td>26:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
# id-trening-axial/freeze-unfreeze/fit-one-cycle-5/lr=1e-5/split-data
save = 0

sname = '3.01_01_train-axial_bias_fr_foc-15_lr-1e4_sp-all'
if save:
    learn.save(sname)

# %%
learn.show_results(rows=2, figsize=(6,6))

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %% [markdown]
# # VERSION 1

# %% [markdown]
# ### LR=1e-3

# %%
lr=1e-3

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022482</td>
#       <td>0.024185</td>
#       <td>0.927332</td>
#       <td>44:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.019372</td>
#       <td>0.021945</td>
#       <td>0.933707</td>
#       <td>1:00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.016431</td>
#       <td>0.022346</td>
#       <td>0.940095</td>
#       <td>24:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014868</td>
#       <td>0.022008</td>
#       <td>0.940431</td>
#       <td>24:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.013972</td>
#       <td>0.022942</td>
#       <td>0.941360</td>
#       <td>24:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
# id-trening-axial/freeze-unfreeze/fit-one-cycle-5/lr=1e-5/split-data
save = 0

sname = '3.01_01_train-axial_bias_fr_foc-05_lr-1e3_sp-all'
if save:
    learn.save(sname)

# %%
learn.load(sname);

# %%
learn.show_results(rows=2, figsize=(6,6))

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_lr()

# %%
learn.recorder.plot_metrics()

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.015497</td>
#       <td>0.020978</td>
#       <td>0.936739</td>
#       <td>31:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.015583</td>
#       <td>0.023624</td>
#       <td>0.939012</td>
#       <td>24:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.014521</td>
#       <td>0.023600</td>
#       <td>0.940659</td>
#       <td>24:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.013275</td>
#       <td>0.023831</td>
#       <td>0.941249</td>
#       <td>24:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.013146</td>
#       <td>0.024106</td>
#       <td>0.941783</td>
#       <td>24:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
save = 0

sname = '3.01_02_train-axial_bias_fr_foc-10_lr-1e3_sp-all'
if save:
    learn.save(sname)

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013930</td>
#       <td>0.024561</td>
#       <td>0.939398</td>
#       <td>58:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.014879</td>
#       <td>0.021378</td>
#       <td>0.937756</td>
#       <td>24:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.013725</td>
#       <td>0.024004</td>
#       <td>0.940311</td>
#       <td>24:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012791</td>
#       <td>0.024235</td>
#       <td>0.941788</td>
#       <td>24:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012466</td>
#       <td>0.024713</td>
#       <td>0.942331</td>
#       <td>24:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
save = 0

sname = '03_train-axial_bias_fr_foc-15_lr-1e3_sp-all'
if save:
    learn.save(sname)

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013280</td>
#       <td>0.022842</td>
#       <td>0.940615</td>
#       <td>24:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.013685</td>
#       <td>0.024374</td>
#       <td>0.940222</td>
#       <td>24:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.012986</td>
#       <td>0.024009</td>
#       <td>0.940515</td>
#       <td>24:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012334</td>
#       <td>0.025540</td>
#       <td>0.941786</td>
#       <td>27:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012199</td>
#       <td>0.025593</td>
#       <td>0.942145</td>
#       <td>24:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
save = 0

sname = '3.01_04_train-axial_bias_fr_foc-20_lr-1e3_sp-all'
if save:
    learn.save(sname)

# %%
learn.unfreeze()

# %%
lrs = slice(lr/5,lr/3)

# %%
learn.fit_one_cycle(5, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.015288</td>
#       <td>0.024044</td>
#       <td>0.940648</td>
#       <td>25:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.013775</td>
#       <td>0.022698</td>
#       <td>0.941543</td>
#       <td>25:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.013187</td>
#       <td>0.022522</td>
#       <td>0.941856</td>
#       <td>25:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012266</td>
#       <td>0.024284</td>
#       <td>0.942135</td>
#       <td>25:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012140</td>
#       <td>0.024349</td>
#       <td>0.942544</td>
#       <td>25:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
save = 0

sname = '3.01_05_train-axial_bias_uf_foc-25_lr-1e3_sp-all'
if save:
    learn.save(sname)
